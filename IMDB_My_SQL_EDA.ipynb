# %% [markdown]
# ## IMPORTS

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

import os, json, math, time
import tmdbsimple as tmdb
from tqdm.notebook import tqdm_notebook

# %% [markdown]
# ### Check Data Files

# %%
FOLDER = 'Data/'
os.makedirs(FOLDER, exist_ok=True)
os.listdir(FOLDER)
# Out:
# ['title_ratings1.csv.gz',
#  'title_basics1.csv.gz',
#  'tmdb_api_results_2000.json',
#  'final_tmdb_data_2000.csv.gz',
#  'tmdb_api_results_2001.json',
#  'title_akas1.csv.gz',
#  'final_tmdb_data_2001.csv.gz',
#  '.ipynb_checkpoints']

# %% [markdown]
# ## LOAD DATA

# %%
df_2000 = pd.read_csv('Data/final_tmdb_data_2000.csv.gz')
df_2000.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0116748    0.0  /wr0hTHwkYIRC82MwNbhOvqrw27N.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 4         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
#
#          id original_language   original_title  ... revenue  runtime  \
# 0       NaN               NaN              NaN  ...     NaN      NaN
# 1   62127.0                en  The Fantasticks  ...     0.0     86.0
# 2  110977.0                en    For the Cause  ...     0.0    100.0
# 3  442869.0                hi             Gang  ...     0.0    152.0
# 4  579396.0                hi         Karobaar  ...     0.0    180.0
#
#                                     spoken_languages    status  \
# 0                                                NaN       NaN
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 4  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
#
#                                          tagline            title  video  \
# 0                                            NaN              NaN    NaN
# 1  Try to remember the first time magic happened  The Fantasticks    0.0
# 2   The ultimate showdown on a forbidden planet.    For the Cause    0.0
# 3                                            NaN             Gang    0.0
# 4                           The Business of Love         Karobaar    0.0
#
#    vote_average vote_count certification
# 0           NaN        NaN           NaN
# 1           5.5       22.0           NaN
# 2           5.1        8.0           NaN
# 3           4.0        1.0           NaN
# 4           7.0        3.0           NaN
#
# [5 rows x 26 columns]

# %%
df_2000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2216 entries, 0 to 2215
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                2216 non-null   object
#  1   adult                  2215 non-null   float64
#  2   backdrop_path          1013 non-null   object
#  3   belongs_to_collection  132 non-null    object
#  4   budget                 2215 non-null   float64
#  5   genres                 2215 non-null   object
#  6   homepage               89 non-null     object
#  7   id                     2215 non-null   float64
#  8   original_language      2215 non-null   object
#  9   original_title         2215 non-null   object
#  10  overview               2026 non-null   object
#  11  popularity             2215 non-null   float64
#  12  poster_path            1903 non-null   object
#  13  production_companies   2215 non-null   object
#  14  production_countries   2215 non-null   object
#  15  release_date           2196 non-null   object
#  16  revenue                2215 non-null   float64
#  17  runtime                2215 non-null   float64
#  18  spoken_languages       2215 non-null   object
#  19  status                 2215 non-null   object
#  20  tagline                650 non-null    object
#  21  title                  2215 non-null   object
#  22  video                  2215 non-null   float64
#  23  vote_average           2215 non-null   float64
#  24  vote_count             2215 non-null   float64
#  25  certification          398 non-null    object
# dtypes: float64(9), object(17)
# memory usage: 450.2+ KB

# %%
df_2001 = pd.read_csv('Data/final_tmdb_data_2001.csv.gz')
df_2001.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0035423    0.0  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg                   NaN
# 2  tt0079644    0.0  /79axmuH1UGkB7m72jjB9rPff9om.jpg                   NaN
# 3  tt0114447    0.0                               NaN                   NaN
# 4  tt0114722    0.0                               NaN                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  48000000.0  [{'id': 10749, 'name': 'Romance'}, {'id': 14, ...      NaN
# 2         0.0                     [{'id': 10752, 'name': 'War'}]      NaN
# 3         0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...      NaN
# 4         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...      NaN
#
#          id original_language    original_title  ...     revenue  runtime  \
# 0       NaN               NaN               NaN  ...         NaN      NaN
# 1   11232.0                en    Kate & Leopold  ...  76019048.0    118.0
# 2  285529.0                id     November 1828  ...         0.0    140.0
# 3  151007.0                en  The Silent Force  ...         0.0     90.0
# 4  276251.0                es          3 Noches  ...         0.0    105.0
#
#                                     spoken_languages    status  \
# 0                                                NaN       NaN
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'Indonesian', 'iso_639_1': '...  Released
# 3  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 4  [{'english_name': 'Spanish', 'iso_639_1': 'es'...  Released
#
#                                              tagline             title  video  \
# 0                                                NaN               NaN    NaN
# 1  If they lived in the same century, they'd be p...    Kate & Leopold    0.0
# 2                                                NaN     November 1828    0.0
# 3  They left him for dead... They should have fin...  The Silent Force    0.0
# 4                                                NaN          3 Nights    0.0
#
#    vote_average vote_count certification
# 0           NaN        NaN           NaN
# 1         6.328     1181.0         PG-13
# 2         0.000        0.0           NaN
# 3         5.000        3.0           NaN
# 4         0.000        0.0           NaN
#
# [5 rows x 26 columns]

# %%
df_2001.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2289 entries, 0 to 2288
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                2289 non-null   object
#  1   adult                  2288 non-null   float64
#  2   backdrop_path          1027 non-null   object
#  3   belongs_to_collection  121 non-null    object
#  4   budget                 2288 non-null   float64
#  5   genres                 2288 non-null   object
#  6   homepage               140 non-null    object
#  7   id                     2288 non-null   float64
#  8   original_language      2288 non-null   object
#  9   original_title         2288 non-null   object
#  10  overview               2131 non-null   object
#  11  popularity             2288 non-null   float64
#  12  poster_path            1965 non-null   object
#  13  production_companies   2288 non-null   object
#  14  production_countries   2288 non-null   object
#  15  release_date           2267 non-null   object
#  16  revenue                2288 non-null   float64
#  17  runtime                2288 non-null   float64
#  18  spoken_languages       2288 non-null   object
#  19  status                 2288 non-null   object
#  20  tagline                637 non-null    object
#  21  title                  2288 non-null   object
#  22  video                  2288 non-null   float64
#  23  vote_average           2288 non-null   float64
#  24  vote_count             2288 non-null   float64
#  25  certification          433 non-null    object
# dtypes: float64(9), object(17)
# memory usage: 465.1+ KB

# %% [markdown]
# ## Combine Data into One DataFrame

# %%
df = pd.concat([df_2000, df_2001], axis = 0)
df.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0116748    0.0  /wr0hTHwkYIRC82MwNbhOvqrw27N.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 4         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
#
#          id original_language   original_title  ... revenue  runtime  \
# 0       NaN               NaN              NaN  ...     NaN      NaN
# 1   62127.0                en  The Fantasticks  ...     0.0     86.0
# 2  110977.0                en    For the Cause  ...     0.0    100.0
# 3  442869.0                hi             Gang  ...     0.0    152.0
# 4  579396.0                hi         Karobaar  ...     0.0    180.0
#
#                                     spoken_languages    status  \
# 0                                                NaN       NaN
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 4  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
#
#                                          tagline            title  video  \
# 0                                            NaN              NaN    NaN
# 1  Try to remember the first time magic happened  The Fantasticks    0.0
# 2   The ultimate showdown on a forbidden planet.    For the Cause    0.0
# 3                                            NaN             Gang    0.0
# 4                           The Business of Love         Karobaar    0.0
#
#    vote_average vote_count certification
# 0           NaN        NaN           NaN
# 1           5.5       22.0           NaN
# 2           5.1        8.0           NaN
# 3           4.0        1.0           NaN
# 4           7.0        3.0           NaN
#
# [5 rows x 26 columns]

# %%
df.dtypes
# Out:
# imdb_id                   object
# adult                    float64
# backdrop_path             object
# belongs_to_collection     object
# budget                   float64
# genres                    object
# homepage                  object
# id                       float64
# original_language         object
# original_title            object
# overview                  object
# popularity               float64
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# revenue                  float64
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# video                    float64
# vote_average             float64
# vote_count               float64
# certification             object
# dtype: object

# %% [markdown]
# ## Perform EDA

# %% [markdown]
# #### How many movies had at least some valid financial information (values > 0 for budget OR revenue)?
# Please exclude any movies with 0's for budget AND revenue from the remaining visualizations.

# %%
fin_info =(df['budget'] > 0) | (df['revenue'] > 0)

# %%
fin_info.value_counts()
# Out:
# False    3769
# True      736
# dtype: int64

# %%
g = sns.countplot(x = fin_info);
sns.set_context('poster')
plt.title('Movies with Positive Financials');
g.set_xticklabels(['No Finacials','Positive Finacials']);

# %% [markdown]
# #### How many movies are there in each of the certification categories (G/PG/PG-13/R)?

# %%
df['certification'].value_counts()
# Out:
# R          471
# PG-13      184
# NR          76
# PG          65
# G           26
# NC-17        7
# Unrated      1
# -            1
# Name: certification, dtype: int64

# %%
sns.barplot(x=df.certification,
           y=df.index)
sns.set_context('poster')
plt.title('Number of Movies in each Certification');
plt.xticks(rotation=45, horizontalalignment='right');
plt.show();

# %% [markdown]
# #### What is the average revenue per certification category?

# %%
df.groupby('certification')['revenue'].mean().round(4)
# Out:
# certification
# -          0.000000e+00
# G          6.663261e+07
# NC-17      1.668286e+03
# NR         2.144835e+06
# PG         6.000680e+07
# PG-13      7.067093e+07
# R          1.600233e+07
# Unrated    0.000000e+00
# Name: revenue, dtype: float64

# %%
sns.barplot(x='certification',
           y='revenue',
           data = df);
sns.set_context('poster');
plt.title('Revenue of each Certification');
plt.xticks(rotation=45, horizontalalignment='right');
plt.show();

# %% [markdown]
# #### What is the average budget per certification category?

# %%
df.groupby('certification')['budget'].mean().round(4)
# Out:
# certification
# -          0.000000e+00
# G          2.205206e+07
# NC-17      0.000000e+00
# NR         1.409738e+06
# PG         2.411534e+07
# PG-13      3.062314e+07
# R          9.622302e+06
# Unrated    0.000000e+00
# Name: budget, dtype: float64

# %%
sns.barplot(x='certification',
           y='budget',
           data = df);
sns.set_context('poster')
plt.title('Budget of each Certification');
plt.xticks(rotation=45, horizontalalignment='right');
plt.show();

# %%
tmdb_results_combined = df

# %%
tmdb_results_combined.to_csv("Data/tmdb_results_combined.csv.gz", compression = 'gzip', index = False)
tmdb_results_combined.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0116748    0.0  /wr0hTHwkYIRC82MwNbhOvqrw27N.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 4         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
#
#          id original_language   original_title  ... revenue  runtime  \
# 0       NaN               NaN              NaN  ...     NaN      NaN
# 1   62127.0                en  The Fantasticks  ...     0.0     86.0
# 2  110977.0                en    For the Cause  ...     0.0    100.0
# 3  442869.0                hi             Gang  ...     0.0    152.0
# 4  579396.0                hi         Karobaar  ...     0.0    180.0
#
#                                     spoken_languages    status  \
# 0                                                NaN       NaN
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 4  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
#
#                                          tagline            title  video  \
# 0                                            NaN              NaN    NaN
# 1  Try to remember the first time magic happened  The Fantasticks    0.0
# 2   The ultimate showdown on a forbidden planet.    For the Cause    0.0
# 3                                            NaN             Gang    0.0
# 4                           The Business of Love         Karobaar    0.0
#
#    vote_average vote_count certification
# 0           NaN        NaN           NaN
# 1           5.5       22.0           NaN
# 2           5.1        8.0           NaN
# 3           4.0        1.0           NaN
# 4           7.0        3.0           NaN
#
# [5 rows x 26 columns]
