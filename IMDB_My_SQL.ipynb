# %% [markdown]
# ## IMPORTS

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## LOAD THE DATA FILES

# %%
basics_url = "https://datasets.imdbws.com/title.basics.tsv.gz"
akas_url = "https://datasets.imdbws.com/title.akas.tsv.gz"
ratings_url = "https://datasets.imdbws.com/title.ratings.tsv.gz"

# %% [markdown]
# ## LOAD AND FILTER BASICS DATA

# %%
basics = pd.read_csv(basics_url, sep='\t', low_memory=False)
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
##Make a coppy of basics
basics1 = basics.copy()

# %%
## Replace Missing Valuess with NaN
basics1.replace({'\\N':np.nan}, inplace = True)

# %%
## Checcking to see if they have changed
basics1.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894     NaN              1         Documentary,Short
# 1       0      1892     NaN              5           Animation,Short
# 2       0      1892     NaN              4  Animation,Comedy,Romance
# 3       0      1892     NaN             12           Animation,Short
# 4       0      1893     NaN              1              Comedy,Short

# %%
## Check for duplicates
basics1.duplicated().sum()
# Out:
# 0

# %%
## Check missing values
basics1.isna().sum()
# Out:
# tconst                  0
# titleType               0
# primaryTitle           11
# originalTitle          11
# isAdult                 1
# startYear         1319110
# endYear           9651666
# runtimeMinutes    6882999
# genres             439371
# dtype: int64

# %% [markdown]
# ### Dropping rows with null values for runtime

# %%
basics1.dropna(subset = ['runtimeMinutes'],inplace=True)
basics1.isna().sum()
# Out:
# tconst                  0
# titleType               0
# primaryTitle            1
# originalTitle           1
# isAdult                 1
# startYear          169432
# endYear           2822811
# runtimeMinutes          0
# genres              76446
# dtype: int64

# %% [markdown]
# ### Dropping rows with missing values for genres

# %%
basics1.dropna(subset = ['genres'],inplace=True)
basics1.isna().sum()
# Out:
# tconst                  0
# titleType               0
# primaryTitle            1
# originalTitle           1
# isAdult                 0
# startYear          164495
# endYear           2747952
# runtimeMinutes          0
# genres                  0
# dtype: int64

# %% [markdown]
# ### Picking only Movies

# %%
basics1 = basics1.loc[basics1['titleType']== 'movie']

# %%
basics1['titleType'].value_counts()
# Out:
# movie    380377
# Name: titleType, dtype: int64

# %% [markdown]
# ### Specifying the years of the movies

# %%
basics1 = basics1.loc[basics1['startYear']>= '2000'] 
basics1 = basics1.loc[basics1['startYear']<= '2022']
basics1['startYear'].value_counts()
# Out:
# 2017    14366
# 2018    14312
# 2019    14037
# 2016    13938
# 2015    13460
# 2014    13090
# 2022    12621
# 2013    12369
# 2021    12298
# 2012    11616
# 2020    11549
# 2011    10765
# 2010    10200
# 2009     9340
# 2008     8142
# 2007     6954
# 2006     6504
# 2005     5817
# 2004     5192
# 2003     4582
# 2002     4127
# 2001     3856
# 2000     3635
# Name: startYear, dtype: int64

# %% [markdown]
# ### Include only fictional movies (not from documentary genre)

# %%
is_documentary = basics1['genres'].str.contains('Documentary',case=False)
basics1 = basics1[~is_documentary]

# %% [markdown]
# ## Inspect the AKAS Data

# %%
akas = pd.read_csv(akas_url, sep = '\t', low_memory = False)
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0

# %%
## Make a copy of data
akas1 = akas.copy()

# %%
akas1 = akas1.loc[akas1['region']== 'US']

# %%
akas1['region'].value_counts()
# Out:
# US    1428057
# Name: region, dtype: int64

# %% [markdown]
# ### Replace "\N" with np.nan

# %%
akas1.replace({'\\N':np.nan}, inplace = True)

# %%
## Check to see if it worked
akas1.head()
# Out:
#       titleId  ordering                   title region language        types  \
# 5   tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 14  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 33  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 36  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 41  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#                attributes isOriginalTitle
# 5                     NaN               0
# 14  literal English title               0
# 33                    NaN               0
# 36                    NaN               0
# 41                    NaN               0

# %%
keepers =basics1['tconst'].isin(akas['titleId'])
keepers
# Out:
# 34803      True
# 61116      True
# 67669      True
# 77964      True
# 86801      True
#            ...
# 9756307    True
# 9756316    True
# 9756355    True
# 9756400    True
# 9756484    True
# Name: tconst, Length: 147191, dtype: bool

# %%
basics1 = basics1[keepers]
basics1
# Out:
#             tconst titleType  \
# 34803    tt0035423     movie
# 61116    tt0062336     movie
# 67669    tt0069049     movie
# 77964    tt0079644     movie
# 86801    tt0088751     movie
# ...            ...       ...
# 9756307  tt9916170     movie
# 9756316  tt9916190     movie
# 9756355  tt9916270     movie
# 9756400  tt9916362     movie
# 9756484  tt9916538     movie
#
#                                               primaryTitle  \
# 34803                                       Kate & Leopold
# 61116    The Tango of the Widower and Its Distorting Mi...
# 67669                           The Other Side of the Wind
# 77964                                        November 1828
# 86801                                    The Naked Monster
# ...                                                    ...
# 9756307                                      The Rehearsal
# 9756316                                          Safeguard
# 9756355                           Il talento del calabrone
# 9756400                                              Coven
# 9756484                                Kuambil Lagi Hatiku
#
#                                      originalTitle isAdult startYear endYear  \
# 34803                               Kate & Leopold       0      2001     NaN
# 61116    El tango del viudo y su espejo deformante       0      2020     NaN
# 67669                   The Other Side of the Wind       0      2018     NaN
# 77964                                November 1828       0      2001     NaN
# 86801                            The Naked Monster       0      2005     NaN
# ...                                            ...     ...       ...     ...
# 9756307                                   O Ensaio       0      2019     NaN
# 9756316                                  Safeguard       0      2020     NaN
# 9756355                   Il talento del calabrone       0      2020     NaN
# 9756400                                   Akelarre       0      2020     NaN
# 9756484                        Kuambil Lagi Hatiku       0      2019     NaN
#
#         runtimeMinutes                     genres
# 34803              118     Comedy,Fantasy,Romance
# 61116               70                      Drama
# 67669              122                      Drama
# 77964              140                  Drama,War
# 86801              100       Comedy,Horror,Sci-Fi
# ...                ...                        ...
# 9756307             51                      Drama
# 9756316             95  Action,Adventure,Thriller
# 9756355             84                   Thriller
# 9756400             92              Drama,History
# 9756484            123                      Drama
#
# [146550 rows x 9 columns]

# %%
ratings = pd.read_csv(ratings_url, sep = '\t', low_memory = False)
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1965
# 1  tt0000002            5.8       262
# 2  tt0000003            6.5      1805
# 3  tt0000004            5.6       178
# 4  tt0000005            6.2      2603

# %%
ratings1 = ratings.copy()

# %%
keepers =ratings1['tconst'].isin(akas['titleId'])
keepers
# Out:
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 1298299     True
# 1298300     True
# 1298301    False
# 1298302    False
# 1298303    False
# Name: tconst, Length: 1298304, dtype: bool

# %%
ratings1 = ratings1[keepers]
ratings1
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1965
# 1        tt0000002            5.8       262
# 2        tt0000003            6.5      1805
# 3        tt0000004            5.6       178
# 4        tt0000005            6.2      2603
# ...            ...            ...       ...
# 1298283  tt9916460            9.4        18
# 1298286  tt9916538            8.6         7
# 1298287  tt9916544            6.9        62
# 1298299  tt9916730            8.3        10
# 1298300  tt9916766            7.0        21
#
# [972187 rows x 3 columns]

# %%
# example making new folder with os
import os
os.makedirs('Data/',exist_ok=True) 
# Confirm folder created
os.listdir("Data/")
# Out:
# ['tmdb_api_results_2000.json',
#  'final_tmdb_data_2000.csv.gz',
#  'tmdb_api_results_2001.json',
#  'final_tmdb_data_2001.csv.gz',
#  '.ipynb_checkpoints',
#  'tmdb_results_combined.csv.gz']

# %%
basics1.to_csv("Data/title_basics1.csv.gz",compression='gzip',index=False)
basics1.head()
# Out:
#           tconst titleType                                       primaryTitle  \
# 34803  tt0035423     movie                                     Kate & Leopold
# 61116  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 67669  tt0069049     movie                         The Other Side of the Wind
# 77964  tt0079644     movie                                      November 1828
# 86801  tt0088751     movie                                  The Naked Monster
#
#                                    originalTitle isAdult startYear endYear  \
# 34803                             Kate & Leopold       0      2001     NaN
# 61116  El tango del viudo y su espejo deformante       0      2020     NaN
# 67669                 The Other Side of the Wind       0      2018     NaN
# 77964                              November 1828       0      2001     NaN
# 86801                          The Naked Monster       0      2005     NaN
#
#       runtimeMinutes                  genres
# 34803            118  Comedy,Fantasy,Romance
# 61116             70                   Drama
# 67669            122                   Drama
# 77964            140               Drama,War
# 86801            100    Comedy,Horror,Sci-Fi

# %%
akas1.to_csv("Data/title_akas1.csv.gz", compression = 'gzip', index = False)
akas1.head()
# Out:
#       titleId  ordering                   title region language        types  \
# 5   tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 14  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 33  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 36  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 41  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#                attributes isOriginalTitle
# 5                     NaN               0
# 14  literal English title               0
# 33                    NaN               0
# 36                    NaN               0
# 41                    NaN               0

# %%
ratings1.to_csv("Data/title_ratings1.csv.gz", compression = 'gzip', index = False)
ratings1.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1965
# 1  tt0000002            5.8       262
# 2  tt0000003            6.5      1805
# 3  tt0000004            5.6       178
# 4  tt0000005            6.2      2603
